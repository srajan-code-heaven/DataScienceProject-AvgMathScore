# %%
#import the required libraries
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.ticker as mtick  
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ScoreData= pd.read_csv('Math_Students_Data_Challenge.csv')

# %% [markdown]
# 1. Understanding Your Variables

# %%
ScoreData.head()
# Out:
#         State  Avg_Math_Score  Avg_English_Score  Total_Enrollment  \
# 0     Alabama        269.1943           257.4278            744548
# 1      Alaska        281.5596           261.2561            131091
# 2     Arizona        279.7223           260.4483            941726
# 3    Arkansas        277.9148           261.9645            477716
# 4  California        275.9014           261.5025           6208733
#
#    State_Debt  State_Revenue  Salaries  Emp_Benefits  Student_Support  \
# 0     5116627        3898347      5045          1884              502
# 1     1321403        1707449      8151          6110             1497
# 2     4270089        2934165      4446          1265              567
# 3     3664741        3847045      5639          1556              484
# 4    54627921       35141208      5567          2085              492
#
#    Inst_Staff_Support
# 0                 400
# 1                1260
# 2                 410
# 3                 798
# 4                 515

# %%
ScoreData.shape
# Out:
# (51, 10)

# %%
ScoreData.columns.values
# Out:
# array(['State', 'Avg_Math_Score', 'Avg_English_Score', 'Total_Enrollment',
#        'State_Debt', 'State_Revenue', 'Salaries', 'Emp_Benefits',
#        'Student_Support', 'Inst_Staff_Support'], dtype=object)

# %%
ScoreData.dtypes
# Out:
# State                  object
# Avg_Math_Score        float64
# Avg_English_Score     float64
# Total_Enrollment        int64
# State_Debt              int64
# State_Revenue           int64
# Salaries                int64
# Emp_Benefits            int64
# Student_Support         int64
# Inst_Staff_Support      int64
# dtype: object

# %%
ScoreData.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#       Avg_Math_Score Avg_English_Score Total_Enrollment       State_Debt  \
# count      51.000000         51.000000        51.000000        51.000000
# mean      283.915004        266.299490    947053.470588   8141932.980392
# std         7.230598          6.004292   1133659.156017  12792789.866990
# min       265.259400        247.739200     44179.000000         0.000000
# 25%       279.773450        261.948000    277190.000000   1313020.500000
# 50%       284.897600        267.215000    671445.000000   4270089.000000
# 75%       288.738500        270.133050   1026836.500000   8848231.500000
# max       300.568200        277.009600   6208733.000000  67957662.000000
#
#          State_Revenue      Salaries Emp_Benefits Student_Support  \
# count        51.000000     51.000000    51.000000       51.000000
# mean    5368677.627451   6486.019608  2545.745098      673.254902
# std     6187873.470679   1547.671147  1084.222428      345.795480
# min           0.000000   3528.000000   953.000000      230.000000
# 25%     1835186.000000   5353.500000  1734.500000      448.500000
# 50%     3693829.000000   6156.000000  2282.000000      551.000000
# 75%     6975934.000000   7272.500000  3155.500000      790.000000
# max    35141208.000000  10385.000000  6110.000000     1843.000000
#
#       Inst_Staff_Support
# count          51.000000
# mean          515.941176
# std           190.090548
# min           243.000000
# 25%           408.000000
# 50%           492.000000
# 75%           552.500000
# max          1260.000000

# %%
missing = pd.DataFrame((ScoreData.isnull().sum())*100/ScoreData.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation =90,fontsize =15)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()
# Out:
# C:\Users\Checkout\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ScoreData.nunique(axis=0)
# Out:
# State                 51
# Avg_Math_Score        51
# Avg_English_Score     51
# Total_Enrollment      51
# State_Debt            50
# State_Revenue         51
# Salaries              51
# Emp_Benefits          50
# Student_Support       50
# Inst_Staff_Support    45
# dtype: int64

# %% [markdown]
# 2. Cleaning your dataset

# %% [markdown]
# a. Removing Redundant variables

# %%
ScoreData=ScoreData.drop(['State','Avg_English_Score'],axis=1)
ScoreData.head(5)
# Out:
#    Avg_Math_Score  Total_Enrollment  State_Debt  State_Revenue  Salaries  \
# 0        269.1943            744548     5116627        3898347      5045
# 1        281.5596            131091     1321403        1707449      8151
# 2        279.7223            941726     4270089        2934165      4446
# 3        277.9148            477716     3664741        3847045      5639
# 4        275.9014           6208733    54627921       35141208      5567
#
#    Emp_Benefits  Student_Support  Inst_Staff_Support
# 0          1884              502                 400
# 1          6110             1497                1260
# 2          1265              567                 410
# 3          1556              484                 798
# 4          2085              492                 515

# %% [markdown]
# b. Checking Variables with Null values

# %%
missing = pd.DataFrame((ScoreData.isnull().sum())*100/ScoreData.shape[0]).reset_index()
plt.figure(figsize=(8,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation =90,fontsize =15)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()
# Out:
# C:\Users\Checkout\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# No values is Missing, therefore Nothing to drop or impute here

# %% [markdown]
# 3. Analyzing relationships between variables

# %% [markdown]
# A. CORRELATION MATRIX

# %%
# plot the heatmap
corr = ScoreData.corr()
plt.figure(figsize=(12,7))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
c = corr
s = c.unstack()
so = s.sort_values(kind="quicksort")
so.tail(20)
# Out:
# Student_Support     Emp_Benefits          0.675914
# Emp_Benefits        Student_Support       0.675914
# Student_Support     Salaries              0.704167
# Salaries            Student_Support       0.704167
# Emp_Benefits        Salaries              0.773999
# Salaries            Emp_Benefits          0.773999
# State_Revenue       State_Debt            0.880598
# State_Debt          State_Revenue         0.880598
#                     Total_Enrollment      0.931701
# Total_Enrollment    State_Debt            0.931701
# State_Revenue       Total_Enrollment      0.939387
# Total_Enrollment    State_Revenue         0.939387
# Avg_Math_Score      Avg_Math_Score        1.000000
# Emp_Benefits        Emp_Benefits          1.000000
# Salaries            Salaries              1.000000
# State_Revenue       State_Revenue         1.000000
# State_Debt          State_Debt            1.000000
# Total_Enrollment    Total_Enrollment      1.000000
# Student_Support     Student_Support       1.000000
# Inst_Staff_Support  Inst_Staff_Support    1.000000
# dtype: float64

# %%
so.head(20)
# Out:
# Student_Support     Total_Enrollment     -0.179102
# Total_Enrollment    Student_Support      -0.179102
# State_Debt          Student_Support      -0.142371
# Student_Support     State_Debt           -0.142371
# Total_Enrollment    Emp_Benefits         -0.108914
# Emp_Benefits        Total_Enrollment     -0.108914
# Total_Enrollment    Salaries             -0.088410
# Salaries            Total_Enrollment     -0.088410
# State_Revenue       Student_Support      -0.074832
# Student_Support     State_Revenue        -0.074832
# State_Debt          Inst_Staff_Support   -0.073484
# Inst_Staff_Support  State_Debt           -0.073484
# Total_Enrollment    Inst_Staff_Support   -0.064150
# Inst_Staff_Support  Total_Enrollment     -0.064150
# Emp_Benefits        State_Debt           -0.046971
# State_Debt          Emp_Benefits         -0.046971
# Salaries            State_Debt           -0.038220
# State_Debt          Salaries             -0.038220
# Avg_Math_Score      Total_Enrollment     -0.034391
# Total_Enrollment    Avg_Math_Score       -0.034391
# dtype: float64

# %% [markdown]
# State_Revenue is Highly Positively Correlated with Total_Enrollment
# State_Debt is Highly Positively Correlated with Total_Enrollment
# State_Debt is Highly Positively Correlated with State_Revenue
# Avg_Math_Score  is Highly Positively Correlated with Avg_English_Score

# %%
plt.figure(figsize=(15,10))
ScoreData.corr()['Avg_Math_Score'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# B. SCATTER PLOT

# %%
sns.pairplot(ScoreData,height=5)
plt.figure(figsize=(7,8))

# %%
ScoreData.drop(['State_Revenue','State_Debt'],axis=1)
# Out:
#     Avg_Math_Score  Total_Enrollment  Salaries  Emp_Benefits  Student_Support  \
# 0         269.1943            744548      5045          1884              502
# 1         281.5596            131091      8151          6110             1497
# 2         279.7223            941726      4446          1265              567
# 3         277.9148            477716      5639          1556              484
# 4         275.9014           6208733      5567          2085              492
# 5         289.6818            851063      5495          1472              418
# 6         285.2440            517812      9601          4255             1079
# 7         282.3383            118685      7620          3728              596
# 8         265.2594             44179      3528          1651              303
# 9         280.8558           2680074      4930          1416              363
# 10        279.1791           1682620      6641          1867              425
# 11        281.4129            184760      6463          2446             1089
# 12        286.4139            272070      7180          1435              377
# 13        284.8976           2069823      6875          3155              830
# 14        287.7677           1002772      5321          2848              458
# 15        285.0701            499489      6511          2171              585
# 16        289.5183            488590      6771          1756              471
# 17        280.6454            685009      5840          2166              429
# 18        272.7610            671156      5800          2738              651
# 19        288.7312            184682      7359          2900              855
# 20        286.6414            859252      8122          3701              629
# 21        300.5682            922848      8822          3315             1112
# 22        280.1336           1381167      5779          3156              869
# 23        294.5930            802454      6997          2282              301
# 24        271.1610            492847      4797          1594              397
# 25        282.9885            897224      6032          1795              453
# 26        289.2285            142797      6180          1890              671
# 27        285.0613            303242      6754          2305              483
# 28        278.2867            431776      4972          1967              444
# 29        295.6651            187703      7653          3304             1057
# 30        296.0534           1338657     10385          4194             1843
# 31        272.7618            327209      5386          1737              897
# 32        281.8078           2629805      9044          5656              615
# 33        285.6454           1468228      5266          1732              443
# 34        290.5151            101025      7186          2384              498
# 35        289.5281           1613718      6744          2575              741
# 36        275.5067            671445      4419          1455              530
# 37        283.5246            564006      5017          2807              684
# 38        289.6237           1623694      8098          3461              750
# 39        284.0922            136401      8509          3702             1637
# 40        279.8246            722249      5681          1929              749
# 41        287.2704            130296      5082          1472              466
# 42        277.7201            992461      5153          1639              381
# 43        288.1990           4897523      5668           953              415
# 44        284.3315            562315      4219          1657              230
# 45        295.4696             89426      9534          3729             1365
# 46        288.1430           1264880      6857          2606              544
# 47        289.9570           1050901      5977          2044              651
# 48        274.4301            282310      6156          3117              551
# 49        288.7458            863737      6149          2866              536
# 50        288.1191             91533      9366          3905              923
#
#     Inst_Staff_Support
# 0                  400
# 1                 1260
# 2                  410
# 3                  798
# 4                  515
# 5                  472
# 6                  511
# 7                  258
# 8                  846
# 9                  523
# 10                 473
# 11                 477
# 12                 293
# 13                 492
# 14                 369
# 15                 495
# 16                 377
# 17                 523
# 18                 542
# 19                 610
# 20                 750
# 21                 856
# 22                 529
# 23                 492
# 24                 408
# 25                 422
# 26                 408
# 27                 362
# 28                 502
# 29                 437
# 30                 563
# 31                 243
# 32                 486
# 33                 275
# 34                 419
# 35                 723
# 36                 332
# 37                 351
# 38                 472
# 39                 522
# 40                 569
# 41                 341
# 42                 542
# 43                 421
# 44                 263
# 45                 760
# 46                 704
# 47                 583
# 48                 461
# 49                 542
# 50                 931

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

y = ScoreData['Avg_Math_Score']
x = ScoreData.drop('Avg_Math_Score',axis=1)
train_x, val_x, train_y, val_y = train_test_split(x, y, random_state=1)

# %%
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(train_y)

my_model = RandomForestClassifier(n_estimators=100,
                                  random_state=0).fit(train_x, training_scores_encoded)

# %%
from sklearn.inspection import permutation_importance
from sklearn.linear_model import Ridge
model = Ridge(alpha=1e-2).fit(train_x, train_y)
model.score(val_x, val_y)
# Out:
# -0.8472726877523589

# %%
# #from eli5.sklearn import PermutationImportance
# from sklearn.inspection import  permutation_importance
# r = permutation_importance(my_model, train_x, train_y,n_repeats=30,random_state=0)


import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(model, random_state=1).fit(val_x, val_y)
eli5.show_weights(perm, feature_names = val_x.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 4.3564
#
#                     &plusmn; 3.0471
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Salaries
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 2.3708
#
#                     &plusmn; 1.1497
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Emp_Benefits
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 1.4240
#
#                     &plusmn; 0.9177
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Total_Enrollment
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1394
#
#                     &plusmn; 0.3766
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Student_Support
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 97.19%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.2635
#
#                     &plusmn; 0.3754
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 State_Debt
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 97.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.2648
#
#                     &plusmn; 0.1276
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Inst_Staff_Support
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 95.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.4499
#
#                     &plusmn; 0.2792
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 State_Revenue
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# Interpreting Permutation Importances
# The values towards the top are the most important features, and those towards the bottom matter least.
#
# The first number in each row shows how much model performance decreased with a random shuffling (in this case, using "accuracy" as the performance metric).
#
# Like most things in data science, there is some randomness to the exact performance change from a shuffling a column. We measure the amount of randomness in our permutation importance calculation by repeating the process with multiple shuffles. The number after the ± measures how performance varied from one-reshuffling to the next.
#
# You'll occasionally see negative values for permutation importances. In those cases, the predictions on the shuffled (or noisy) data happened to be more accurate than the real data. This happens when the feature didn't matter (should have had an importance close to 0), but random chance caused the predictions on shuffled data to be more accurate. This is more common with small datasets, like the one in this example, because there is more room for luck/chance.
#
# In our example, the most important feature was Salaries. That seems sensible. Soccer fans may have some intuition about whether the orderings of other variables are surprising or not
